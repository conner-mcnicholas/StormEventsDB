# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
from pyspark.sql.types import ArrayType, DoubleType, BooleanType
from pyspark.sql.functions import *
from builtins import round as pyround
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
schema_details = StructType([
    StructField("BEGIN_YEARMONTH", StringType(),True),
    StructField("BEGIN_DAY", StringType(),True),
    StructField("BEGIN_TIME", StringType(),True),
    StructField("END_YEARMONTH", StringType(),True),
    StructField("END_DAY", StringType(),True),
    StructField("END_TIME", StringType(),True),
    StructField("EPISODE_ID", IntegerType(),True),
    StructField("EVENT_ID", IntegerType(),True),
    StructField("STATE", StringType(),True),
    StructField("STATE_FIPS", IntegerType(),True),
    StructField("YEAR", IntegerType(),True),
    StructField("MONTH_NAME", StringType(),True),
    StructField("EVENT_TYPE", StringType(),True),
    StructField("CZ_TYPE", StringType(),True),
    StructField("CZ_FIPS", IntegerType(),True),
    StructField("CZ_NAME", StringType(),True),
    StructField("WFO", StringType(),True),
    StructField("BEGIN_DATE_TIME", StringType(),True),
    StructField("CZ_TIMEZONE", StringType(),True),
    StructField("END_DATE_TIME", StringType(),True),
    StructField("INJURIES_DIRECT", IntegerType(),True),
    StructField("INJURIES_INDIRECT", IntegerType(),True),
    StructField("DEATHS_DIRECT", IntegerType(),True),
    StructField("DEATHS_INDIRECT", IntegerType(),True),
    StructField("DAMAGE_PROPERTY", StringType(),True),
    StructField("DAMAGE_CROPS", StringType(),True),
    StructField("SOURCE", StringType(),True),
    StructField("MAGNITUDE", DoubleType(),True),
    StructField("MAGNITUDE_TYPE", StringType(),True),
    StructField("FLOOD_CAUSE", StringType(),True),
    StructField("CATEGORY", IntegerType(),True),
    StructField("TOR_F_SCALE", StringType(),True),
    StructField("TOR_LENGTH", DoubleType(),True),
    StructField("TOR_WIDTH", IntegerType(),True),
    StructField("TOR_OTHER_WFO", StringType(),True),
    StructField("TOR_OTHER_CZ_STATE", StringType(),True),
    StructField("TOR_OTHER_CZ_FIPS", IntegerType(),True),
    StructField("TOR_OTHER_CZ_NAME", StringType(),True),
    StructField("BEGIN_RANGE", IntegerType(),True),
    StructField("BEGIN_AZIMUTH", StringType(),True),
    StructField("BEGIN_LOCATION", StringType(),True),
    StructField("END_RANGE", IntegerType(),True),
    StructField("END_AZIMUTH", StringType(),True),
    StructField("END_LOCATION", StringType(),True),
    StructField("BEGIN_LAT", DoubleType(),True),
    StructField("BEGIN_LON", DoubleType(),True),
    StructField("END_LAT", DoubleType(),True),
    StructField("END_LON", DoubleType(),True),
    StructField("EPISODE_NARRATIVE",StringType(),True),
    StructField("EVENT_NARRATIVE",StringType(),True),
    StructField("DATA_SOURCE", StringType(),True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
schema_fatalities = StructType([
    StructField("FAT_YEARMONTH", StringType(),True),
    StructField("FAT_DAY", StringType(),True),
    StructField("FAT_TIME", StringType(),True),
    StructField("FATALITY_ID", IntegerType(),True),
    StructField("EVENT_ID", IntegerType(),True),
    StructField("FATALITY_TYPE", StringType(),True),
    StructField("FATALITY_DATE", StringType(),True),
    StructField("FATALITY_AGE", IntegerType(),True),
    StructField("FATALITY_SEX", StringType(),True),
    StructField("FATALITY_LOCATION",IntegerType(),True),
    StructField("EVENT_YEARMONTH",StringType(),True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
storage_account_name = "pipelinestorageacctaus"
storage_account_access_key = "f6fWRdrrX8qYB9a1y2Rlgu7qCuyeHuD59j3UIb0hi3ZanAn8DUmej+uofzFi7irJm954fTa5LtBb+AStzjJHYA=="
spark_blob_container = "sparkstorestorm"
blob_container = "allfiles"
"""
for mount in dbutils.fs.mounts():
    print(mount.mountPoint == '/mnt/storm') 

if not any(mount.mountPoint == '/mnt/storm/' for mount in dbutils.fs.mounts()):
    try:
        dbutils.fs.mount(
        source = "wasbs://{}@{}.blob.core.windows.net".format(spark_blob_container, storage_account_name),
        mount_point = "/mnt/storm",
        extra_configs = {'fs.azure.account.key.' + storage_account_name + '.blob.core.windows.net': storage_account_access_key})
    except Exception as e:
        print("already mounted. Try to unmount first")

display(dbutils.fs.ls("dbfs:/mnt/mountfolder/data"))
"""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &#39;\nfor mount in dbutils.fs.mounts():\n    print(mount.mountPoint == \&#39;/mnt/storm\&#39;) \n\nif not any(mount.mountPoint == \&#39;/mnt/storm/\&#39; for mount in dbutils.fs.mounts()):\n    try:\n        dbutils.fs.mount(\n        source = &#34;wasbs://{}@{}.blob.core.windows.net&#34;.format(spark_blob_container, storage_account_name),\n        mount_point = &#34;/mnt/storm&#34;,\n        extra_configs = {\&#39;fs.azure.account.key.\&#39; + storage_account_name + \&#39;.blob.core.windows.net\&#39;: storage_account_access_key})\n    except Exception as e:\n        print(&#34;already mounted. Try to unmount first&#34;)\n\ndisplay(dbutils.fs.ls(&#34;dbfs:/mnt/mountfolder/data&#34;))\n&#39;</div>

# %%
detPath = "wasbs://allfiles@pipelinestorageacctaus.blob.core.windows.net/details/*.gz"

df_details = spark.read.format("csv").option("header", True).schema(schema_details).load("wasbs://allfiles@pipelinestorageacctaus.blob.core.windows.net/details/*.gz")

print('count of details loaded to spark: ' +  str(df_details.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of details loaded to spark: 1744028
# </div>

# %%
print('count of fatalities loaded to spark: ' + str(df_fatalities.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of fatalities loaded to spark: 20394
# </div>

# %%
print('count of fatalities loaded to spark partitioned as parquet: '+str(fatalities_autopart.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of fatalities loaded to spark partitioned as parquet: 20394
# </div>

# %%
df_fatalities.groupBy('FATALITY_TYPE').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-----+
# FATALITY_TYPE|count|
# +-------------+-----+
#             D|17313|
#             I| 3081|
# +-------------+-----+
#
# </div>

# %%
fatalities_autopart.groupBy('FATALITY_TYPE').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-----+
# FATALITY_TYPE|count|
# +-------------+-----+
#             D|17313|
#             I| 3081|
# +-------------+-----+
#
# </div>

# %%
print('counting full fatalities:')
print(f'\tdefault partition vs non-partitioned speedup = {pyround(.62/.3,2)}x')
print('\ncounting fatalities by fatality_type:')
print(f'\tdefault partition vs non-partitioned speedup = {pyround(.71/.37,2)}x')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">counting full fatalities:
# 	default partition vs non-partitioned speedup = 2.07x
#
# counting fatalities by fatality_type:
# 	default partition vs non-partitioned speedup = 1.92x
# </div>

# %%
fatPath = "wasbs://"  + blob_container + "@" + storage_account_name + ".blob.core.windows.net/fatalities/*.gz"

df_fatalities = spark.read.format("csv").option("header", True).schema(schema_fatalities).load(fatPath)

print('count of fatalities loaded to spark: ' + str(df_fatalities.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of fatalities loaded to spark: 20394
# </div>

# %%
df_details.createOrReplaceTempView("details")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def mon_to_num(string):
    m = {
        'jan':'01',
        'feb':'02',
        'mar':'03',
        'apr':'04',
        'may':'05',
        'jun':'06',
        'jul':'07',
        'aug':'08',
        'sep':'09',
        'oct':'10',
        'nov':'11',
        'dec':'12'}
    s = string.strip()[:3].lower()

    try:
        out = m[s]
        return out
    except:
        raise ValueError('Not a month')
spark.udf.register("mon_to_num", lambda str: mon_to_num(str) if not str is None else "" , StringType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: &lt;function __main__.&lt;lambda&gt;(str)&gt;</div>

# %%
details_ltd =\
    spark.sql("SELECT \
        TO_TIMESTAMP(CONCAT(LEFT(BEGIN_M_DATE_TIME,3),mon_to_num(SUBSTR(BEGIN_M_DATE_TIME,4,3)),RIGHT(BEGIN_M_DATE_TIME,5),RIGHT(BEGIN_DATE_TIME,9)),'dd-MM-yyyy HH:mm:ss') AS BEGIN_TIMESTAMP,\
        TO_TIMESTAMP(CONCAT(LEFT(END_M_DATE_TIME,3),mon_to_num(SUBSTR(END_M_DATE_TIME,4,3)),RIGHT(END_M_DATE_TIME,5),RIGHT(END_DATE_TIME,9)),'dd-MM-yyyy HH:mm:ss') AS END_TIMESTAMP,\
        EPISODE_ID,EVENT_ID,STATE,CZ_NAME AS LOCALITY,EVENT_TYPE,\
        (DEATHS_DIRECT+DEATHS_INDIRECT) AS DEATHS,\
        (INJURIES_DIRECT+INJURIES_INDIRECT) AS INJURIES,\
            CASE\
            WHEN RIGHT(DAMAGE_PROPERTY, 1) = 'K' THEN ROUND(1000.00*CAST(LEFT(DAMAGE_PROPERTY,LENGTH(DAMAGE_PROPERTY)-1) AS DECIMAL(5,2)),2)\
            WHEN RIGHT(DAMAGE_PROPERTY, 1) = 'M' THEN ROUND(1000000.00*CAST(LEFT(DAMAGE_PROPERTY,LENGTH(DAMAGE_PROPERTY)-1) AS DECIMAL(5,2)),2)\
            WHEN RIGHT(DAMAGE_PROPERTY, 1) = 'B' THEN ROUND(1000000000.00*CAST(LEFT(DAMAGE_PROPERTY,LENGTH(DAMAGE_PROPERTY)-1) AS DECIMAL(5,2)),2)\
            WHEN DAMAGE_PROPERTY IS NULL THEN 0.00\
            ELSE ROUND(CAST(DAMAGE_PROPERTY AS DECIMAL(5,2)),2)\
        END AS DAMAGED_PROPERTY,\
            CASE\
            WHEN RIGHT(DAMAGE_CROPS, 1) = 'K' THEN ROUND(1000.00*CAST(LEFT(DAMAGE_CROPS,LENGTH(DAMAGE_CROPS)-1) AS DECIMAL(5,2)),2)\
            WHEN RIGHT(DAMAGE_CROPS, 1) = 'M' THEN ROUND(1000000.00*CAST(LEFT(DAMAGE_CROPS,LENGTH(DAMAGE_CROPS)-1) AS DECIMAL(5,2)),2)\
            WHEN RIGHT(DAMAGE_CROPS, 1) = 'B' THEN ROUND(1000000000.00*CAST(LEFT(DAMAGE_CROPS,LENGTH(DAMAGE_CROPS)-1) AS DECIMAL(5,2)),2)\
            WHEN DAMAGE_CROPS IS NULL THEN 0.00\
            ELSE ROUND(CAST(DAMAGE_CROPS AS DECIMAL(5,2)),2)\
        END AS DAMAGED_CROPS,\
        BEGIN_LAT,BEGIN_LON,END_LAT,END_LON\
        FROM (SELECT \
            CASE WHEN CAST(SUBSTR(BEGIN_DATE_TIME,8,2) AS INTEGER) > 30 THEN LEFT(CONCAT(LEFT(BEGIN_DATE_TIME,7),'19',RIGHT(BEGIN_DATE_TIME,11)),11)\
            ELSE LEFT(CONCAT(LEFT(BEGIN_DATE_TIME,7),'20',RIGHT(BEGIN_DATE_TIME,11)),11)\
        END AS BEGIN_M_DATE_TIME,\
            CASE WHEN CAST(SUBSTR(END_DATE_TIME,8,2) AS INTEGER) > 30 THEN LEFT(CONCAT(LEFT(END_DATE_TIME,7),'19',RIGHT(END_DATE_TIME,11)),11)\
            ELSE LEFT(CONCAT(LEFT(END_DATE_TIME,7),'20',RIGHT(END_DATE_TIME,11)),11)\
        END AS END_M_DATE_TIME,details.* \
        FROM details) d1 order by 1,2,3,4")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_ltd.filter("EPISODE_ID IS NOT NULL AND DEATHS+INJURIES>0 AND (DAMAGED_PROPERTY NOT LIKE '0.00' OR DAMAGED_CROPS NOT LIKE '0.00') AND BEGIN_LAT IS NOT NULL AND LOCALITY NOT LIKE '%/%'").show(50,truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-------------------+----------+---------+--------------+------------+-----------------+------+--------+----------------+-------------+---------+---------+-------+-------+
# BEGIN_TIMESTAMP    |END_TIMESTAMP      |EPISODE_ID|EVENT_ID |STATE         |LOCALITY    |EVENT_TYPE       |DEATHS|INJURIES|DAMAGED_PROPERTY|DAMAGED_CROPS|BEGIN_LAT|BEGIN_LON|END_LAT|END_LON|
# +-------------------+-------------------+----------+---------+--------------+------------+-----------------+------+--------+----------------+-------------+---------+---------+-------+-------+
# 1972-06-18 15:13:00|1972-06-18 15:13:00|990000001 |990000002|FLORIDA       |HENDRY      |Tornado          |1     |1       |10000.00        |5000.00      |26.73    |-81.47   |26.77  |-81.48 |
# 1972-06-18 15:17:00|1972-06-18 15:17:00|990000001 |990000001|FLORIDA       |GLADES      |Tornado          |0     |6       |190000.00       |5000.00      |26.77    |-81.48   |26.78  |-81.48 |
# 1972-06-18 22:55:00|1972-06-18 22:55:00|990000001 |990000003|FLORIDA       |OKEECHOBEE  |Tornado          |6     |44      |500000.00       |0.00         |27.21    |-80.8    |27.27  |-80.8  |
# 1996-01-03 08:07:00|1996-01-03 08:12:00|2404254   |5536210  |FLORIDA       |MIAMI-DADE  |Tornado          |0     |9       |1200000.00      |0.00         |25.68    |-80.42   |25.75  |-80.33 |
# 1996-03-16 13:15:00|1996-03-16 13:18:00|2030296   |5546758  |ALABAMA       |JACKSON     |Tornado          |0     |2       |85000.00        |0.00         |34.7     |-85.8    |34.72  |-85.77 |
# 1996-03-16 16:05:00|1996-03-16 16:10:00|2029923   |5548009  |TENNESSEE     |OVERTON     |Tornado          |0     |1       |5500000.00      |0.00         |36.38    |-85.33   |36.4   |-85.22 |
# 1996-03-16 18:15:00|1996-03-16 18:45:00|2029841   |5547121  |TENNESSEE     |SCOTT       |Tornado          |0     |1       |160000.00       |0.00         |36.5     |-84.52   |36.5   |-84.52 |
# 1996-03-18 17:30:00|1996-03-18

# %%
spark.sql("SELECT STATE,COUNT(*) FROM details group by 1 order by 2 desc").show(50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+--------+
#          STATE|count(1)|
# +--------------+--------+
#          TEXAS|  139444|
#         KANSAS|   83144|
#       OKLAHOMA|   69390|
#       MISSOURI|   63253|
#           IOWA|   61673|
#       ILLINOIS|   55274|
#       NEBRASKA|   55084|
#       VIRGINIA|   49437|
#        GEORGIA|   48704|
#       NEW YORK|   48378|
#      MINNESOTA|   48226|
# NORTH CAROLINA|   48203|
#       KENTUCKY|   47691|
#   SOUTH DAKOTA|   46559|
#   PENNSYLVANIA|   46390|
#           OHIO|   45399|
#       COLORADO|   43407|
#       ARKANSAS|   43176|
#      WISCONSIN|   40245|
#      TENNESSEE|   38525|
#        INDIANA|   37480|
#        ALABAMA|   37016|
#        FLORIDA|   35262|
#    MISSISSIPPI|   34886|
#       MICHIGAN|   32689|
#     CALIFORNIA|   31470|
#        MONTANA|   30269|
#   NORTH DAKOTA|   29253|
# SOUTH CAROLINA|   28616|
#      LOUISIANA|   26900|
#     NEW JERSEY|   24145|
#  WEST VIRGINIA|   23316|
#        WYOMING|   22218|
#       MARYLAND|   21761|
#     NEW MEXICO|   19795|
#  MASSACHUSETTS|   14907|
#         HAWAII|   14339|
# GULF OF MEXICO|   14091|
#          MAINE|   13828|
#        ARIZONA|   13611|
# ATLANTIC NORTH|   11259|
#         OREGON|   10180|
#           UTAH|    9809|
#          IDAHO|    9672|
#        VERMONT|    9539|
#     WASHINGTON|    8785|
#         ALASKA|    8391|
#  NEW HAMPSHIRE|    7504|
# ATLANTIC SOUTH|    7102|
#         NEVADA|    6503|
# +--------------+--------+
# only showing top 50 rows
#
# </div>

# %%
spark.sql("SELECT CAST(LEFT(BEGIN_YEARMONTH,4) AS INT) AS YEAR,COUNT(*) FROM details group by 1 order by 2 desc").show(50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------+
# YEAR|count(1)|
# +----+--------+
# 2011|   79091|
# 2008|   71190|
# 2019|   67859|
# 2012|   64503|
# 2010|   62807|
# 2018|   62693|
# 2020|   61237|
# 2021|   61108|
# 2013|   59986|
# 2014|   59476|
# 2007|   59010|
# 2015|   57906|
# 2009|   57398|
# 2017|   57030|
# 2006|   56400|
# 2016|   56005|
# 2005|   53976|
# 2003|   52956|
# 2004|   52409|
# 2000|   52007|
# 1998|   50973|
# 2002|   50936|
# 2001|   48875|
# 1996|   48569|
# 1999|   46383|
# 1997|   41983|
# 2022|   21405|
# 1995|   20465|
# 1994|   15627|
# 1992|   13534|
# 1991|   12516|
# 1990|   10945|
# 1989|   10407|
# 1986|    8725|
# 1993|    8664|
# 1983|    8322|
# 1985|    7979|
# 1987|    7363|
# 1984|    7335|
# 1988|    7257|
# 1982|    7126|
# 1980|    6136|
# 1974|    5375|
# 1975|    4975|
# 1981|    4517|
# 1973|    4453|
# 1979|    4279|
# 1976|    3768|
# 1977|    3728|
# 1978|    3657|
# +----+--------+
# only showing top 50 rows
#
# </div>

# %%
details_ltd.createOrReplaceTempView('details_ltd')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_ltd=details_ltd.withColumn('year',year(details_ltd.BEGIN_TIMESTAMP))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_parted20=spark.sql("SELECT 88850*FLOOR(ROWNUM/88850) AS PARTN,d1.* FROM (SELECT ROW_NUMBER() OVER (ORDER BY BEGIN_TIMESTAMP,END_TIMESTAMP,EPISODE_ID,EVENT_ID) AS ROWNUM,details_ltd.* FROM details_ltd) d1 ORDER BY ROWNUM")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_parted=spark.sql("SELECT 218920*FLOOR(ROWNUM/218920) AS PARTN,d1.* FROM (SELECT ROW_NUMBER() OVER (ORDER BY BEGIN_TIMESTAMP,END_TIMESTAMP,EPISODE_ID,EVENT_ID) AS ROWNUM,details_ltd.* FROM details_ltd) d1 ORDER BY ROWNUM")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_parted.createOrReplaceTempView('details_parted')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql('select PARTN,count(*) from details_parted group by 1 order by 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+
#   PARTN|count(1)|
# +-------+--------+
#       0|  218919|
#  218920|  218920|
#  437840|  218920|
#  656760|  218920|
#  875680|  218920|
# 1094600|  218920|
# 1313520|  218920|
# 1532440|  211589|
# +-------+--------+
#
# </div>

# %%
df_fatalities=df_fatalities.withColumn('FATALITY_DATE',when(df_fatalities.EVENT_ID == 402331, '07/04/2012 11:00:00')\
                         .when(df_fatalities.EVENT_ID == 402384, '07/18/2012 11:00:00').\
                         otherwise(df_fatalities.FATALITY_DATE))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_fatalities.createOrReplaceTempView('fatalities')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_fatalities.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-------+--------+-----------+--------+-------------+-------------------+------------+------------+-----------------+---------------+
# FAT_YEARMONTH|FAT_DAY|FAT_TIME|FATALITY_ID|EVENT_ID|FATALITY_TYPE|      FATALITY_DATE|FATALITY_AGE|FATALITY_SEX|FATALITY_LOCATION|EVENT_YEARMONTH|
# +-------------+-------+--------+-----------+--------+-------------+-------------------+------------+------------+-----------------+---------------+
#        201104|     15|       0|       9144|  289571|            D|04/15/2011 00:00:00|           7|           M|             null|         999999|
#        201104|     26|       0|       9730|  289592|            D|04/26/2011 00:00:00|           1|           M|             null|         999999|
#        201104|     25|       0|       9138|  289612|            D|04/25/2011 00:00:00|          63|           M|             null|         999999|
#        201104|     25|       0|       9139|  289612|            D|04/25/2011 00:00:00|          55|           M|             null|         999999|
#        201104|     25|       0|       9140|  289612|            D|04/25/2011 00:00:00|          45|           M|             null|         999999|
#        201104|     25|       0|       9141|  289612|            D|04/25/2011 00:00:00|          45|           F|             null|         999999|
#        201103|     19|       0|       8793|  290103|            D|03/19/2011 00:00:00|          46|           M|             null|         999999|
#        201103|     16|       0|       8792|  290109|            D|03/16/2011 00:00:00|          35|           M|             null|         999999|
#        201104|     27|       0|       8753|  290116|            D|04/27/2011 00:00:00|          22|           M|             null|         999999|
#        201104|     27|       0|       8754|  290116|            D|04/27/2011 00:00:00|          18|           M|             null|         999999|
#        201104|     27|       0|       8755|  290116|            D|04/27/2011 00:00:00|          12|           M|             null|         999999|
#        201103|     22|       0|       8756|  290503|            I|03/22/2011 00:00:00|          69|           F|             null|         999999|
#        201104|     11|       0|      16435|  290523|            D|04/11/2011 00:00:00|          26|           M|             null|         999999|
#        201102|      8|       0|       8757|  290786|            D|02/08/2011 00:00:00|          33|           M|             null|         999999|
#        201104|     15|       0|       8764|  290951|            D|04/15/2011 00:00:00|           6|           M|             null|         999999|
#        201104|     15|       0|       8763|  290952|            D|04/15/2011 00:00:00|          56|           M|             null|         999999|
#        201104|     15|       0|       8765|  290959|            D|04/15/2011 00:00:00|          24|           M|             null|         999999|
#        201104|     15|       0|       8766|  290959|            D|04/15/2011 00:00:00|           1|           F|             null|         999999|
#        201103|     21|       0|       8786|  290997|            I|03/21/2011 00:00:00|          65|           F|             null|         999999|
#        201102|      3|       0|       8777|  291087|            I|02/03/2011 00:00:00|        null|        null|             null|         999999|
# +-------------+-------+--------+-----------+--------+-------------+-------------------+------------+------------+-----------------+---------------+
# only showing top 20 rows
#
# </div>

# %%
fatalities_ltd=spark.sql("SELECT \
        CASE WHEN SUBSTR(FATALITY_DATE,2,1) = '/' AND LEFT(RIGHT(FATALITY_DATE,6),1) = ':' THEN TO_TIMESTAMP(FATALITY_DATE,'M/dd/yyyy HH:mm:ss') \
             WHEN SUBSTR(FATALITY_DATE,2,1) = '/' AND LEFT(RIGHT(FATALITY_DATE,6),1) = ' ' THEN TO_TIMESTAMP(FATALITY_DATE,'M/dd/yyyy HH:mm') \
             ELSE TO_TIMESTAMP(FATALITY_DATE,'MM/dd/yyyy HH:mm:ss') \
        END AS FATALITY_TIMESTAMP,\
        * FROM fatalities order by FATALITY_TIMESTAMP,EVENT_ID,FATALITY_ID")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fatalities_ltd=fatalities_ltd.withColumn('year',year(fatalities_ltd.FATALITY_TIMESTAMP))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fatalities_ltd.createOrReplaceTempView('fatalities_ltd')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fatalities_parted=spark.sql("select 2560*FLOOR(ROWNUM/2560) AS PARTN,f1.* FROM (SELECT ROW_NUMBER() OVER (ORDER BY FATALITY_TIMESTAMP,EVENT_ID,FATALITY_ID) AS ROWNUM,fatalities_ltd.* from fatalities_ltd) f1 ORDER BY ROWNUM")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fatalities_parted20=spark.sql("select 1020*FLOOR(ROWNUM/1020) AS PARTN,f1.* FROM (SELECT ROW_NUMBER() OVER (ORDER BY FATALITY_TIMESTAMP,EVENT_ID,FATALITY_ID) AS ROWNUM,fatalities_ltd.* from fatalities_ltd) f1 ORDER BY ROWNUM")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# 17920| 20378|2022-04-13 00:00:00|       202204|     13|       0|      46224| 1012040|            D|04/13/2022 00:00:00|        null|           F|             null|         202204|2022|
# 17920| 20377|2022-04-13 00:00:00|       202204|     13|       0|      46223| 1012040|            D|04/13/2022 00:00:00|        null|           M|             null|         202204|2022|
# 17920| 20376|2022-04-13 00:00:00|       202204|     13|       0|      46106| 1008720|            D|04/13/2022 00:00:00|          18|           F|             null|         202204|2022|
# 17920| 20375|2022-04-10 00:00:00|       202204|     10|       0|      46348| 1021301|            D|04/10/2022 00:00:00|          44|           M|             null|         202204|2022|
# +-----+------+-------------------+-------------+-------+--------+-----------+--------+-------------+-------------------+------------+------------+-----------------+---------------+----+
# only showing top 20 rows
#
# </div>

# %%
spark.sql('select PARTN,count(*) from fatalities_parted group by 1 order by 1').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------+
# PARTN|count(1)|
# +-----+--------+
#     0|    2559|
#  2560|    2560|
#  5120|    2560|
#  7680|    2560|
# 10240|    2560|
# 12800|    2560|
# 15360|    2560|
# 17920|    2475|
# +-----+--------+
#
# </div>

# %%
#details_ltd.write.partitionBy("year").mode("overwrite").parquet("dbfs:/mnt/storm/details")
#fatalities_ltd.write.partitionBy("year").mode("overwrite").parquet("dbfs:/mnt/storm/fatalities")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
details_parted.write.partitionBy("PARTN").mode("overwrite").parquet("dbfs:/mnt/storm/details")
fatalities_parted.write.partitionBy("PARTN").mode("overwrite").parquet("dbfs:/mnt/storm/fatalities")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_parted20.write.partitionBy("PARTN").mode("overwrite").parquet("dbfs:/mnt/storm/details_part20")
fatalities_parted20.write.partitionBy("PARTN").mode("overwrite").parquet("dbfs:/mnt/storm/fatalities_part20")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_ltd.write.mode("overwrite").parquet("dbfs:/mnt/storm/details_autopart")
fatalities_ltd.write.mode("overwrite").parquet("dbfs:/mnt/storm/fatalities_autopart")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_dist=spark.read.format("parquet").load('/mnt/storm/details/')
print('count of details loaded to spark partitioned as parquet: '+str(details_dist.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of details loaded to spark partitioned as parquet: 1744028
# </div>

# %%
details_autopart=spark.read.format("parquet").load('/mnt/storm/details_autopart/')
print('count of details loaded to spark partitioned as default partitioned parquet: '+str(details_autopart.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of details loaded to spark partitioned as default partitioned parquet: 1744028
# </div>

# %%
details_dist20=spark.read.format("parquet").load('/mnt/storm/details_part20/')
print('count of details loaded to spark partitionedx20 as parquet: '+str(details_dist.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of details loaded to spark partitionedx20 as parquet: 1744028
# </div>

# %%
print('count of fatalities loaded to spark nonpartitioned: '+str(df_fatalities.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of fatalities loaded to spark nonpartitioned: 20394
# </div>

# %%
fatalities_autopart=spark.read.format("parquet").load('/mnt/storm/fatalities_autopart/')
print('count of fatalities loaded to spark partitioned as parquet: '+str(fatalities_autopart.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of fatalities loaded to spark partitioned as parquet: 20394
# </div>

# %%
df_details = spark.read.format("csv").option("header", True).schema(schema_details).load("wasbs://allfiles@pipelinestorageacctaus.blob.core.windows.net/details/*.gz")
print('count of details loaded to spark nonpartitioned: ' +  str(df_details.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count of details loaded to spark nonpartitioned: 1744028
# </div>

# %%
details_autopart.groupBy(['year']).count().orderBy('year',ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# year|count|
# +----+-----+
# 2022|21405|
# 2021|61108|
# 2020|61237|
# 2019|67859|
# 2018|62693|
# 2017|57030|
# 2016|56005|
# 2015|57906|
# 2014|59476|
# 2013|59986|
# +----+-----+
# only showing top 10 rows
#
# </div>

# %%
details_autopart.groupBy(['year','STATE','EVENT_TYPE']).count().orderBy(['year','STATE','EVENT_TYPE'],ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+--------------------+-----+
# year|  STATE|          EVENT_TYPE|count|
# +----+-------+--------------------+-----+
# 2022|WYOMING|      Winter Weather|   32|
# 2022|WYOMING|        Winter Storm|   45|
# 2022|WYOMING|   Thunderstorm Wind|    1|
# 2022|WYOMING|           High Wind|  198|
# 2022|WYOMING|          Heavy Snow|   36|
# 2022|WYOMING|                Hail|    4|
# 2022|WYOMING|Extreme Cold/Wind...|   37|
# 2022|WYOMING|     Cold/Wind Chill|    7|
# 2022|WYOMING|            Blizzard|   11|
# 2022|WYOMING|           Avalanche|    2|
# +----+-------+--------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
print(f'count(DISTINCT(EVENT_TYPE)) = {details_autopart.select("EVENT_TYPE").distinct().count()}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count(DISTINCT(EVENT_TYPE)) = 70
# </div>

# %%
sc = SparkContext

def count_elements(splitIndex, iterator):
    n = sum(1 for _ in iterator)
    yield (splitIndex, n)
    
numparts = details_autopart.rdd.getNumPartitions()
sc.parallelize(numSlices=numparts,c)
details_def_rdd = sc.parallelize(range(0,numparts), numparts).map(lambda x: (x, x)).cache()
sizeparts = details_def_rdd.mapPartitionsWithIndex(lambda ind, x: count_elements(ind, x)).take(numparts)
#sizeparts = details_autopart.rdd.mapPartitionsWithIndex(lambda x,it: [(x,sum(1 for _ in it))]).collect()
#minsize=min(sizeparts,key=lambda item:item[1])
#maxsize=max(sizeparts,key=lambda item:item[1])
#print(f'default partitioning of details table created {numparts} partitions, with sizes of {sizeparts}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4058641340200236&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> numparts <span class="ansi-blue-fg">=</span> details_autopart<span class="ansi-blue-fg">.</span>rdd<span class="ansi-blue-fg">.</span>getNumPartitions<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 8</span><span class="ansi-red-fg"> </span>details_def_rdd <span class="ansi-blue-fg">=</span> sc<span class="ansi-blue-fg">.</span>parallelize<span class="ansi-blue-fg">(</span>range<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">,</span>numparts<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> numparts<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>map<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> x<span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">(</span>x<span class="ansi-blue-fg">,</span> x<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>cache<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      9</span> sizeparts <span class="ansi-blue-fg">=</span> details_def_rdd<span class="ansi-blue-fg">.</span>mapPartitionsWithIndex<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> ind<span class="ansi-blue-fg">,</span> x<span class="ansi-blue-fg">:</span> count_elements<span class="ansi-blue-fg">(</span>ind<span class="ansi-blue-fg">,</span> x<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>take<span class="ansi-blue-fg">(</span>numparts<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     10</span> <span class="ansi-red-fg">#sizeparts = details_autopart.rdd.mapPartitionsWithIndex(lambda x,it: [(x,sum(1 for _ in it))]).collect()</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/context.py</span> in <span class="ansi-cyan-fg">parallelize</span><span class="ansi-blue-fg">(self, c, numSlices)</span>
# <span class="ansi-green-intense-fg ansi-bold">    554</span>         <span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">4</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">    555</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 556</span><span class="ansi-red-fg">         </span>numSlices <span class="ansi-blue-fg">=</span> int<span class="ansi-blue-fg">(</span>numSlices<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">if</span> numSlices <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span> <span class="ansi-green-fg">else</span> self<span class="ansi-blue-fg">.</span>defaultParallelism
# <span class="ansi-green-intense-fg ansi-bold">    557</span>         <span class="ansi-green-fg">if</span> isinstance<span class="ansi-blue-fg">(</span>c<span class="ansi-blue-fg">,</span> range<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    558</span>             size <span class="ansi-blue-fg">=</span> len<span class="ansi-blue-fg">(</span>c<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;range&#39; object has no attribute &#39;defaultParallelism&#39;</div>

# %%
details_dist.withColumn('year',year(details_dist.BEGIN_TIMESTAMP)).groupBy(['year']).count().orderBy('year',ascending=False).show(10)
#details_dist.groupBy(['year']).count().orderBy('year',ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# year|count|
# +----+-----+
# 2022|21405|
# 2021|61108|
# 2020|61237|
# 2019|67859|
# 2018|62693|
# 2017|57030|
# 2016|56005|
# 2015|57906|
# 2014|59476|
# 2013|59986|
# +----+-----+
# only showing top 10 rows
#
# </div>

# %%
#df_details = spark.read.format("csv").option("header", True).schema(schema_details).load("wasbs://allfiles@pipelinestorageacctaus.blob.core.windows.net/details/*.gz")
df_details.groupBy(['YEAR']).count().orderBy('YEAR',ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# YEAR|count|
# +----+-----+
# 2022|21405|
# 2021|61108|
# 2020|61237|
# 2019|67859|
# 2018|62693|
# 2017|57030|
# 2016|56005|
# 2015|57906|
# 2014|59476|
# 2013|59986|
# +----+-----+
# only showing top 10 rows
#
# </div>

# %%
details_dist20=details_dist20.withColumn('year',year(details_dist20.BEGIN_TIMESTAMP))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_dist20.groupBy(['year']).count().orderBy('year',ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# year|count|
# +----+-----+
# 2022|21405|
# 2021|61108|
# 2020|61237|
# 2019|67859|
# 2018|62693|
# 2017|57030|
# 2016|56005|
# 2015|57906|
# 2014|59476|
# 2013|59986|
# +----+-----+
# only showing top 10 rows
#
# </div>

# %%
details_dist.createOrReplaceTempView('details_dist')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(f'count(DISTINCT(EVENT_TYPE)) = {details_dist.select("EVENT_TYPE").distinct().count()}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count(DISTINCT(EVENT_TYPE)) = 70
# </div>

# %%
spark.sql('select count(distinct(EVENT_TYPE)) from details_dist').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------------+
# count(DISTINCT EVENT_TYPE)|
# +--------------------------+
#                         70|
# +--------------------------+
#
# </div>

# %%
spark.sql('select count(distinct(EVENT_TYPE)) from details').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------------+
# count(DISTINCT EVENT_TYPE)|
# +--------------------------+
#                         70|
# +--------------------------+
#
# </div>

# %%
print(f'count(DISTINCT(EVENT_TYPE)) = {details_dist20.select("EVENT_TYPE").distinct().count()}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count(DISTINCT(EVENT_TYPE)) = 70
# </div>

# %%
details_dist.withColumn('year',year(details_dist.BEGIN_TIMESTAMP)).groupBy(['year','STATE','EVENT_TYPE']).count().orderBy(['year','STATE','EVENT_TYPE'],ascending=False).show(10)
#details_dist.groupBy(['year']).count().orderBy('year',ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+--------------------+-----+
# year|  STATE|          EVENT_TYPE|count|
# +----+-------+--------------------+-----+
# 2022|WYOMING|      Winter Weather|   32|
# 2022|WYOMING|        Winter Storm|   45|
# 2022|WYOMING|   Thunderstorm Wind|    1|
# 2022|WYOMING|           High Wind|  198|
# 2022|WYOMING|          Heavy Snow|   36|
# 2022|WYOMING|                Hail|    4|
# 2022|WYOMING|Extreme Cold/Wind...|   37|
# 2022|WYOMING|     Cold/Wind Chill|    7|
# 2022|WYOMING|            Blizzard|   11|
# 2022|WYOMING|           Avalanche|    2|
# +----+-------+--------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
df_details.groupBy(['year','STATE','EVENT_TYPE']).count().orderBy(['year','STATE','EVENT_TYPE'],ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+--------------------+-----+
# year|  STATE|          EVENT_TYPE|count|
# +----+-------+--------------------+-----+
# 2022|WYOMING|      Winter Weather|   32|
# 2022|WYOMING|        Winter Storm|   45|
# 2022|WYOMING|   Thunderstorm Wind|    1|
# 2022|WYOMING|           High Wind|  198|
# 2022|WYOMING|          Heavy Snow|   36|
# 2022|WYOMING|                Hail|    4|
# 2022|WYOMING|Extreme Cold/Wind...|   37|
# 2022|WYOMING|     Cold/Wind Chill|    7|
# 2022|WYOMING|            Blizzard|   11|
# 2022|WYOMING|           Avalanche|    2|
# +----+-------+--------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
details_disty = details_dist.withColumn('year',year(details_dist.BEGIN_TIMESTAMP))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
details_disty.groupBy(['year','STATE','EVENT_TYPE']).count().orderBy(['year','STATE','EVENT_TYPE'],ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+--------------------+-----+
# year|  STATE|          EVENT_TYPE|count|
# +----+-------+--------------------+-----+
# 2022|WYOMING|      Winter Weather|   32|
# 2022|WYOMING|        Winter Storm|   45|
# 2022|WYOMING|   Thunderstorm Wind|    1|
# 2022|WYOMING|           High Wind|  198|
# 2022|WYOMING|          Heavy Snow|   36|
# 2022|WYOMING|                Hail|    4|
# 2022|WYOMING|Extreme Cold/Wind...|   37|
# 2022|WYOMING|     Cold/Wind Chill|    7|
# 2022|WYOMING|            Blizzard|   11|
# 2022|WYOMING|           Avalanche|    2|
# +----+-------+--------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
details_dist20.groupBy(['year','STATE','EVENT_TYPE']).count().orderBy(['year','STATE','EVENT_TYPE'],ascending=False).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+--------------------+-----+
# year|  STATE|          EVENT_TYPE|count|
# +----+-------+--------------------+-----+
# 2022|WYOMING|      Winter Weather|   32|
# 2022|WYOMING|        Winter Storm|   45|
# 2022|WYOMING|   Thunderstorm Wind|    1|
# 2022|WYOMING|           High Wind|  198|
# 2022|WYOMING|          Heavy Snow|   36|
# 2022|WYOMING|                Hail|    4|
# 2022|WYOMING|Extreme Cold/Wind...|   37|
# 2022|WYOMING|     Cold/Wind Chill|    7|
# 2022|WYOMING|            Blizzard|   11|
# 2022|WYOMING|           Avalanche|    2|
# +----+-------+--------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
df_details.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[357]: 1744028</div>

# %%
details_dist.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[352]: 1744028</div>

# %%
details_dist20.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[354]: 1744028</div>

# %%
details_autopart.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[356]: 1744028</div>

# %%
print('This cluster has 2 worker nodes with each node having 4 CPU cores = 8 total CPU cores.\n\nI chose explicit parquet partitions count of:\n\t8 (i.e. 1 partition per core)\n\t20 (per Spark documentation recommendation of 2.5 tasks per core)\n\nIn addition, I also tested the default partitioning given when not explictly defining the partioning scheme:\n\t9 partitions of details / 1 partition for fatalities.\n\nFinally, I benchmarked each against the non-partitioned, non-parquet dataframe given by importing the source csvs')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">This cluster has 2 worker nodes with each node having 4 CPU cores = 8 total CPU cores.
#
# I chose explicit parquet partitions count of:
# 	8 (i.e. 1 partition per core)
# 	20 (per Spark documentation recommendation of 2.5 tasks per core)
#
# In addition, I also tested the default partitioning given when not explictly defining the partioning scheme of:
# 	9 partitions of details / 1 partition for fatalities.
#
# Finally, I benchmarked each against the non-partitioned, non-parquet dataframe given by importing the source csvs
# </div>

# %%
print('speedups = ratio of elapsed time using each of the following vs non-partitioned:\n\t 1)  8 parquet partitions\n\t 2)  9 parquet partitions (DEFAULT, i.e. no separate folders per partition)\n\t 3) 20 parquet partitions')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">speedups = ratio of elapsed time using each of the following vs non-partitioned:
# 	 1)  8 parquet partitions
# 	 2)  9 parquet partitions (DEFAULT, i.e. no separate folders per partition)
# 	 3) 20 parquet partitions
# </div>

# %%
print('count full details:')
print(f'\tspeedup 1 = {pyround(3.43/.26,2)}x')
print(f'\tspeedup 2 = {pyround(3.43/.22,2)}x')
print(f'\tspeedup 3 =  {pyround(3.43/.43,2)}x')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">count full details:
# 	speedup 1 = 13.19x
# 	speedup 2 = 15.59x
# 	speedup 3 =  7.98x
# </div>

# %%
print('counting distinct details event_types:')
print(f'\tspeedup 1 = {pyround(4.44/.44,2)}x')
print(f'\tspeedup 2 =  {pyround(4.44/.54,2)}x')
print(f'\tspeedup 3 =  {pyround(4.44/.69,2)}x')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">counting distinct details event_types:
# 	speedup 1 = 10.09x
# 	speedup 2 =  8.22x
# 	speedup 3 =  6.43x
# </div>

# %%
print('counting details by year:')
print(f'\tspeedup 1 =  {pyround(4.24/.57,2)}x')
print(f'\tspeedup 2 = {pyround(4.24/.36,2)}x')
print(f'\tspeedup 3 =  {pyround(4.24/.73,2)}x')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">counting details by year:
# 	speedup 1 =  7.44x
# 	speedup 2 = 11.78x
# 	speedup 3 =  5.81x
# </div>

# %%
print('counting details by year,state, and event_type:')
print(f'\tspeedup 1 - {pyround(4.65/.77,2)}x')
print(f'\tspeedup 2 = {pyround(4.65/.62,2)}0x')
print(f'\tspeedup 3 = {pyround(4.65/.85,2)}x')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">counting details by year,state, and event_type:
# 	speedup 1 - 6.04x
# 	speedup 2 = 7.50x
# 	speedup 3 = 5.47x
# </div>
